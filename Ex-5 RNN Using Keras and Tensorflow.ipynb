# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import SimpleRNN, Dense
from sklearn.metrics import r2_score

# --- 1. Generate Synthetic Time-Series Data ---
np.random.seed(0)
seq_length = 10
num_samples = 1000
X = np.random.randn(num_samples, seq_length, 1)
y = X.sum(axis=1) + 0.1 * np.random.randn(num_samples, 1)

# --- 2. Split Data into Training and Testing Sets ---
split_ratio = 0.8
split_index = int(split_ratio * num_samples)
X_train, X_test = X[:split_index], X[split_index:]
y_train, y_test = y[:split_index], y[split_index:]

# --- 3. Build the SimpleRNN Model ---
model = Sequential()
model.add(SimpleRNN(units=50, activation='relu', input_shape=(seq_length, 1)))
model.add(Dense(units=1))

# --- 4. Compile and Train the Model ---
model.compile(optimizer='adam', loss='mean_squared_error')
model.summary()

batch_size = 30
epochs = 50
history = model.fit(
    X_train, y_train,
    batch_size=batch_size,
    epochs=epochs,
    validation_split=0.2
)

# --- 5. Evaluate the Model ---
test_loss = model.evaluate(X_test, y_test)
print(f'\nTest Loss: {test_loss:.4f}')

# Calculate R-squared for accuracy
y_pred = model.predict(X_test)
r2 = r2_score(y_test, y_pred)
print(f'Test Accuracy (R^2): {r2:.4f}')

# --- 6. Make Predictions on New Data ---
new_data = np.random.randn(5, seq_length, 1)
predictions = model.predict(new_data)
print("\nPredictions for new data:")
print(predictions)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn_1 (SimpleRNN)    (None, 50)                2600
#
#  dense_1 (Dense)             (None, 1)                 51
#
# =================================================================
# Total params: 2,651
# Trainable params: 2,651
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 22/22 [==============================] - 3s 26ms/step - loss: 8.6365 - val_loss: 6.1788
# Epoch 2/50
# 22/22 [==============================] - 0s 9ms/step - loss: 5.4496 - val_loss: 1.8444
# Epoch 3/50
# 22/22 [==============================] - 0s 9ms/step - loss: 1.3328 - val_loss: 1.0006
# Epoch 4/50
# 22/22 [==============================] - 0s 9ms/step - loss: 0.5730 - val_loss: 0.4432
# Epoch 5/50
# 22/22 [==============================] - 0s 10ms/step - loss: 0.3213 - val_loss: 0.3056
# Epoch 6/50
# 22/22 [==============================] - 0s 13ms/step - loss: 0.2205 - val_loss: 0.1747
# Epoch 7/50
# 22/22 [==============================] - 0s 7ms/step - loss: 0.1226 - val_loss: 0.1849
# Epoch 8/50
# 22/22 [==============================] - 0s 7ms/step - loss: 0.0975 - val_loss: 0.1026
# Epoch 9/50
# 22/22 [==============================] - 0s 7ms/step - loss: 0.0714 - val_loss: 0.0790
# Epoch 10/50
# 22/22 [==============================] - 0s 9ms/step - loss: 0.0527 - val_loss: 0.0819
# Epoch 11/50
# 22/22 [==============================] - 0s 10ms/step - loss: 0.0467 - val_loss: 0.0711
# Epoch 12/50
# 22/22 [==============================] - 0s 8ms/step - loss: 0.0509 - val_loss: 0.0605
# Epoch 13/50
# 22/22 [==============================] - 0s 7ms/step - loss: 0.0372 - val_loss: 0.0487
# Epoch 14/50
# 22/22 [==============================] - 0s 10ms/step - loss: 0.0334 - val_loss: 0.0492
# Epoch 15/50
# 22/22 [==============================] - 0s 9ms/step - loss: 0.0467 - val_loss: 0.0629
# Epoch 16/50
# 22/22 [==============================] - 0s 7ms/step - loss: 0.0298 - val_loss: 0.0395
# Epoch 17/50
# 22/22 [==============================] - 0s 7ms/step - loss: 0.0304 - val_loss: 0.0443
# Epoch 18/50
# 22/22 [==============================] - 0s 9ms/step - loss: 0.0289 - val_loss: 0.0499
# Epoch 19/50
# 22/22 [==============================] - 0s 8ms/step - loss: 0.0265 - val_loss: 0.0404
# Epoch 20/50
# 22/22 [==============================] - 0s 8ms/step - loss: 0.0283 - val_loss: 0.0432
# Epoch 21/50
# 22/22 [==============================] - 0s 10ms/step - loss: 0.0430 - val_loss: 0.0553
# Epoch 22/50
# 22/22 [==============================] - 0s 9ms/step - loss: 0.0437 - val_loss: 0.0652
# Epoch 23/50
# 22/22 [==============================] - 0s 8ms/step - loss: 0.0300 - val_loss: 0.0763
# Epoch 24/50
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0715 - val_loss: 0.0387
# Epoch 25/50
# 22/22 [==============================] - 0s 8ms/step - loss: 0.0284 - val_loss: 0.0439
# Epoch 26/50
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0223 - val_loss: 0.0323
# Epoch 27/50
# 22/22 [==============================] - 0s 7ms/step - loss: 0.0190 - val_loss: 0.0459
# Epoch 28/50
# 22/22 [==============================] - 0s 7ms/step - loss: 0.0227 - val_loss: 0.0321
# Epoch 29/50
# 22/22 [==============================] - 0s 7ms/step - loss: 0.0211 - val_loss: 0.0413
# Epoch 30/50
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0195 - val_loss: 0.0346
# Epoch 31/50
# 22/22 [==============================] - 0s 8ms/step - loss: 0.0162 - val_loss: 0.0269
# Epoch 32/50
# 22/22 [==============================] - 0s 7ms/step - loss: 0.0209 - val_loss: 0.0265
# Epoch 33/50
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0172 - val_loss: 0.0286
# Epoch 34/50
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0176 - val_loss: 0.0299
# Epoch 35/50
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0170 - val_loss: 0.0284
# Epoch 36/50
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0175 - val_loss: 0.0303
# Epoch 37/50
# 22/22 [==============================] - 0s 7ms/step - loss: 0.0167 - val_loss: 0.0267
# Epoch 38/50
# 22/22 [==============================] - 0s 7ms/step - loss: 0.0182 - val_loss: 0.0463
# Epoch 39/50
# 22/22 [==============================] - 0s 7ms/step - loss: 0.0209 - val_loss: 0.0386
# Epoch 40/50
# 22/22 [==============================] - 0s 8ms/step - loss: 0.0198 - val_loss: 0.0345
# Epoch 41/50
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0193 - val_loss: 0.0374
# Epoch 42/50
# 22/22 [==============================] - 0s 7ms/step - loss: 0.0214 - val_loss: 0.0250
# Epoch 43/50
# 22/22 [==============================] - 0s 7ms/step - loss: 0.0207 - val_loss: 0.0284
# Epoch 44/50
# 22/22 [==============================] - 0s 8ms/step - loss: 0.0177 - val_loss: 0.0376
# Epoch 45/50
# 22/22 [==============================] - 0s 7ms/step - loss: 0.0216 - val_loss: 0.0388
# Epoch 46/50
# 22/22 [==============================] - 0s 7ms/step - loss: 0.0153 - val_loss: 0.0314
# Epoch 47/50
# 22/22 [==============================] - 0s 7ms/step - loss: 0.0138 - val_loss: 0.0374
# Epoch 48/50
# 22/22 [==============================] - 0s 7ms/step - loss: 0.0218 - val_loss: 0.0409
# Epoch 49/50
# 22/22 [==============================] - 0s 7ms/step - loss: 0.0182 - val_loss: 0.0265
# Epoch 50/50
# 22/22 [==============================] - 0s 7ms/step - loss: 0.0222 - val_loss: 0.0308
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0271
#
# Test Loss: 0.0271
# 7/7 [==============================] - 0s 3ms/step
# Test Accuracy (R^2): 0.9971
# 1/1 [==============================] - 0s 30ms/step
#
# Predictions for new data:
# [[ 1.5800741 ]
#  [ 0.45606533]
#  [-2.1480823 ]
#  [-0.5292473 ]
#  [-3.9469688 ]]
